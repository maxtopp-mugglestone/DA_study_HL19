# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil
import numpy as np
# Local imports
import analysis_functions

# Apply better style
analysis_functions.apply_heatmap_style()

# %% [markdown]
# ### Plot tune scan

# %%
# Define study
STUDY_NAME = "HL19_tunescan"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0016/config.yaml"

# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Out:
#                    name base collider  normalized amplitude in xy-plane_x  \
# beam qx     qy
# b1   62.305 60.309      base_collider                               4.000
#             60.310      base_collider                               4.031
#             60.311      base_collider                               4.250
#             60.312      base_collider                               4.031
#             60.313      base_collider                               4.625
# ...                               ...                                 ...
#      62.323 60.328      base_collider                               4.000
#             60.329      base_collider                               4.000
#      62.324 60.328      base_collider                               4.000
#             60.329      base_collider                               4.000
#      62.325 60.329      base_collider                               4.000
#
#                     normalized amplitude in xy-plane_y      qx      qy  dqx  \
# beam qx     qy
# b1   62.305 60.309                               4.000  62.305  60.309   15
#             60.310                               4.031  62.305  60.310   15
#             60.311                               4.250  62.305  60.311   15
#             60.312                               4.031  62.305  60.312   15
#             60.313                               4.625  62.305  60.313   15
# ...                                                ...     ...     ...  ...
#      62.323 60.328                               4.000  62.323  60.328   15
#             60.329                               4.000  62.323  60.329   15
#      62.324 60.328                               4.000  62.324  60.328   15
#             60.329                               4.000  62.324  60.329   15
#      62.325 60.329                               4.000  62.325  60.329   15
#
#                     dqy  i_bunch_b1  i_bunch_b2  i_oct_b1  i_oct_b2  \
# beam qx     qy
# b1   62.305 60.309   15        1963        1963      -235      -235
#             60.310   15        1963        1963      -235      -235
#             60.311   15        1963        1963      -235      -235
#             60.312   15        1963        1963      -235      -235
#             60.313   15        1963        1963      -235      -235
# ...                 ...         ...         ...       ...       ...
#      62.323 60.328   15        1963        1963      -235      -235
#             60.329   15        1963        1963      -235      -235
#      62.324 60.328   15        1963        1963      -235      -235
#             60.329   15        1963        1963      -235      -235
#      62.325 60.329   15        1963        1963      -235      -235
#
#                    num_particles_per_bunch  crossing_angle
# beam qx     qy
# b1   62.305 60.309                  2.2e11           250.0
#             60.310                  2.2e11           250.0
#             60.311                  2.2e11           250.0
#             60.312                  2.2e11           250.0
#             60.313                  2.2e11           250.0
# ...                                    ...             ...
#      62.323 60.328                  2.2e11           250.0
#             60.329                  2.2e11           250.0
#      62.324 60.328                  2.2e11           250.0
#             60.329                  2.2e11           250.0
#      62.325 60.329                  2.2e11           250.0
#
# [211 rows x 13 columns]

# %%
#normalised_amplitude_xy_plane = np.sqrt(df["normalized amplitude in xy-plane_x"]**2 + df["normalized amplitude in xy-plane_y"]**2)

# %%
#df.insert(4, "normalized amplitude in xy-plane", normalised_amplitude_xy_plane)

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane_x")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.309   4.000     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310   4.031   4.000     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311   4.250   4.062   4.031     NaN     NaN     NaN     NaN     NaN
# 60.312   4.031   4.094   4.062   4.062     NaN     NaN     NaN     NaN
# 60.313   4.625   4.250   4.000   4.000   4.188     NaN     NaN     NaN
# 60.314   4.188   4.125   4.031   4.000   4.094     NaN     NaN     NaN
# 60.315   4.406   4.031   4.062   4.000   4.125     NaN     NaN     NaN
# 60.316   4.719   4.031   4.125   4.000     NaN   5.188   5.281     NaN
# 60.317   4.625   4.031   4.094   4.000   4.062   5.438   5.469     NaN
# 60.318   4.188   4.000   4.062   4.000   4.531   5.469   5.375   5.625
# 60.319   4.438   4.156   4.250   4.062   4.312   5.312   5.438     NaN
# 60.320   4.156   4.469   4.000   4.031   4.344   5.062   5.094     NaN
# 60.321   4.031   4.031   4.250   4.000   4.406   4.406   4.750     NaN
# 60.322   4.125   4.062   4.031   4.000   4.156   4.312   4.312   4.656
# 60.323   4.000   4.000   4.000   4.000   4.125   4.094   4.031   4.031
# 60.324   4.000   4.031   4.031   4.000   4.000   4.000   4.031   4.000
# 60.325   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.326   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.327   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.328   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.329   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
#
# qx      62.313  62.314  ...  62.316  62.317  62.318  62.319  62.320  62.321  \
# qy                      ...
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317   5.562     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.318   5.344     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.319     NaN   5.750  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.320   5.312   5.281  ...   5.750     NaN     NaN     NaN     NaN     NaN
# 60.321   4.781     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.322   4.281   4.750  ...   5.312     NaN     NaN     NaN     NaN     NaN
# 60.323   4.000   4.312  ...   4.031     NaN     NaN     NaN     NaN     NaN
# 60.324   4.094   4.000  ...   4.031   4.031     4.0   4.219   4.125     NaN
# 60.325   4.000   4.000  ...   4.000   4.000     4.0   4.000   4.000   4.031
# 60.326   4.000   4.000  ...   4.000   4.000     4.0   4.000   4.000   4.000
# 60.327   4.000   4.000  ...   4.000   4.000     4.0   4.000   4.000   4.000
# 60.328   4.000   4.000  ...   4.000   4.000     4.0   4.000   4.000   4.000
# 60.329   4.000   4.000  ...   4.000   4.000     4.0   4.000   4.000   4.000
#
# qx      62.322  62.323  62.324  62.325
# qy
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323     NaN     NaN     NaN     NaN
# 60.324     NaN     NaN     NaN     NaN
# 60.325     NaN     NaN     NaN     NaN
# 60.326     4.0     NaN     NaN     NaN
# 60.327     4.0     4.0     NaN     NaN
# 60.328     4.0     4.0     4.0     NaN
# 60.329     4.0     4.0     4.0     4.0
#
# [21 rows x 21 columns]

# %%
# Replace NaNs above the upper diagonal with 8
fill_nan = True

if fill_nan:
    for qx in df_to_plot.columns:
        for qy in df_to_plot.index:
            if qy >= qx - 2 + 0.004:
                if pd.isna(df_to_plot.loc[qy, qx]):
                    df_to_plot.loc[qy, qx] = 8

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    f'{STUDY_NAME}_{COLLIDER}',
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flathv",
    betx=0.5,
    bety=0.5,
    Nb=True,
    green_contour=6.,
    extended_diagonal=False,
    vmin=4.,
    vmax=8.0,
    CC = True,
)
#! Verified
# Out:
# Luminosity not found in config, setting to None

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane_y")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.309   4.000     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310   4.031   4.031     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311   4.250   4.188   4.031     NaN     NaN     NaN     NaN     NaN
# 60.312   4.125   4.094   4.062   4.062     NaN     NaN     NaN     NaN
# 60.313   4.625   4.250   4.031   4.000     NaN     NaN     NaN     NaN
# 60.314   4.438     NaN   4.031   4.000     NaN     NaN     NaN     NaN
# 60.315   4.406   4.031   4.062   4.000     NaN     NaN     NaN     NaN
# 60.316   4.719     NaN   4.125   4.094     NaN     NaN     NaN     NaN
# 60.317   4.625   4.031     NaN     NaN     NaN     NaN     NaN     NaN
# 60.318   4.188   4.000     NaN   4.000     NaN     NaN   5.375     NaN
# 60.319   4.438   4.156   4.250   4.062     NaN     NaN   5.438     NaN
# 60.320   4.156   4.469     NaN   4.031     NaN   5.719     NaN     NaN
# 60.321   4.031     NaN     NaN   4.000     NaN   4.406     NaN     NaN
# 60.322   4.125   4.062   4.031   4.094   4.156     NaN     NaN     NaN
# 60.323   4.000   4.000   4.000   4.031   4.125   4.094   4.031   4.031
# 60.324   4.031   4.031   4.031   4.000   4.000   4.000   4.031   4.031
# 60.325   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.326   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.327   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.328   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.329   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
#
# qx      62.313  62.314  ...  62.316  62.317  62.318  62.319  62.320  62.321  \
# qy                      ...
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317   5.562     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.323   4.000   4.406  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.324   4.094   4.000  ...     NaN   4.031     4.0     NaN     NaN     NaN
# 60.325   4.031   4.000  ...     4.0   4.000     4.0     4.0     4.0   4.031
# 60.326   4.000   4.000  ...     4.0   4.000     4.0     4.0     4.0   4.000
# 60.327   4.000   4.000  ...     4.0   4.000     4.0     4.0     4.0   4.000
# 60.328   4.000   4.000  ...     4.0   4.000     4.0     4.0     4.0   4.000
# 60.329   4.000   4.000  ...     4.0   4.000     4.0     4.0     4.0   4.000
#
# qx      62.322  62.323  62.324  62.325
# qy
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323     NaN     NaN     NaN     NaN
# 60.324     NaN     NaN     NaN     NaN
# 60.325     NaN     NaN     NaN     NaN
# 60.326     4.0     NaN     NaN     NaN
# 60.327     4.0     4.0     NaN     NaN
# 60.328     4.0     4.0     4.0     NaN
# 60.329     4.0     4.0     4.0     4.0
#
# [21 rows x 21 columns]

# %%
# Replace NaNs above the upper diagonal with 8
for qx in df_to_plot.columns:
    for qy in df_to_plot.index:
        if qy >= qx - 2 + 0.004:
            if pd.isna(df_to_plot.loc[qy, qx]):
                df_to_plot.loc[qy, qx] = 8

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    f'{STUDY_NAME}_{COLLIDER}',
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flathv",
    betx=1.1,
    bety=1.1,
    Nb=True,
    green_contour=6.,
    extended_diagonal=False,
    vmin=4.,
    vmax=8.0,
    CC = True,
)
#! Verified
# Out:
# Luminosity not found in config, setting to None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 4
#       2 conf_mad = analysis_functions.load_config(CONF_MAD_PATH)
#       3 conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
# ----> 4 analysis_functions.plot_heatmap(
#       5     df_to_plot,
#       6     f'{STUDY_NAME}_{COLLIDER}',
#       7     link=None,
#       8     plot_contours=True,
#       9     conf_mad=conf_mad,
#      10     conf_collider=conf_collider,
#      11     type_crossing="flathv",
#      12     betx=1.1,
#      13     bety=1.1,
#      14     Nb=True,
#      15     green_contour=6.,
#      16     extended_diagonal=False,
#      17     vmin=4.,
#      18     vmax=8.0,
#      19     CC = True,
#      20 )
#      21 #! Verified
#
# File /afs/cern.ch/work/t/toppmugg/private/DA_HL19/studies/analysis/analysis_functions.py:468, in plot_heatmap(df_to_plot, study_name, link, plot_contours, conf_mad, conf_collider, type_crossing, betx, bety, Nb, levelling, CC, xlabel, ylabel, symmetric, mask_lower_triangle, mask_upper_triangle, plot_diagonal_lines, xaxis_ticks_on_top, title, add_vline, display_intensity, vmin, vmax, extended_diagonal, green_contour)
#     465     plt.axvline(add_vline, color="black", linestyle="--", linewidth=1)
#     466     plt.text(add_vline, 25, r"Bunch intensity $\simeq \beta^*_{2023} = 0.3/0.3$", fontsize=8)
# --> 468 plt.savefig("plots/output_" + study_name + ".pdf", bbox_inches="tight")
#     469 plt.show()
#
# File /afs/cern.ch/work/t/toppmugg/private/miniforge_ar/envs/env_ar_clean/lib/python3.10/site-packages/matplotlib/pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File /afs/cern.ch/work/t/toppmugg/private/miniforge_ar/envs/env_ar_clean/lib/python3.10/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /afs/cern.ch/work/t/toppmugg/private/miniforge_ar/envs/env_ar_clean/lib/python3.10/site-packages/matplotlib/backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File /afs/cern.ch/work/t/toppmugg/private/miniforge_ar/envs/env_ar_clean/lib/python3.10/site-packages/matplotlib/backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File /afs/cern.ch/work/t/toppmugg/private/miniforge_ar/envs/env_ar_clean/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:2779, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2777     file = filename._ensure_file()
#    2778 else:
# -> 2779     file = PdfFile(filename, metadata=metadata)
#    2780 try:
#    2781     file.newPage(width, height)
#
# File /afs/cern.ch/work/t/toppmugg/private/miniforge_ar/envs/env_ar_clean/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:687, in PdfFile.__init__(self, filename, metadata)
#     685 self.original_file_like = None
#     686 self.tell_base = 0
# --> 687 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     688 if not opened:
#     689     try:
#
# File /afs/cern.ch/work/t/toppmugg/private/miniforge_ar/envs/env_ar_clean/lib/python3.10/site-packages/matplotlib/cbook.py:546, in to_filehandle(fname, flag, return_opened, encoding)
#     544         fh = bz2.BZ2File(fname, flag)
#     545     else:
# --> 546         fh = open(fname, flag, encoding=encoding)
#     547     opened = True
#     548 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plots/output_HL19_tunescan_base_collider.pdf'

# %%
print(df['normalized amplitude in xy-plane_x'])
# Out:
# beam  qx      qy
# b1    62.305  60.309    4.000
#               60.310    4.031
#               60.311    4.250
#               60.312    4.125
#               60.313    4.625
#                         ...
#       62.323  60.328    4.000
#               60.329    4.000
#       62.324  60.328    4.000
#               60.329    4.000
#       62.325  60.329    4.000
# Name: normalized amplitude in xy-plane_x, Length: 166, dtype: float64

# %%
print(df['normalized amplitude in xy-plane_y'])
# Out:
# beam  qx      qy
# b1    62.305  60.309    4.000
#               60.310    4.031
#               60.311    4.250
#               60.312    4.125
#               60.313    4.625
#                         ...
#       62.323  60.328    4.000
#               60.329    4.000
#       62.324  60.328    4.000
#               60.329    4.000
#       62.325  60.329    4.000
# Name: normalized amplitude in xy-plane_y, Length: 166, dtype: float64
